# %%
import numpy as np
import pandas as pd
from datetime import datetime, date

import sys
from itertools import combinations, groupby
from collections import Counter
from IPython.display import display

from sklearn.cluster import KMeans

# %%
AP = 'dec_AP.csv'
ML = 'dec_ML.csv'

# %%
orders = pd.read_csv(f'../data/monthwise/{AP}', index_col=0)
item_name   = pd.read_csv('../data/itemlist.csv', index_col=0)
mlDF = pd.read_csv(f"../data/monthwise/{ML}")

# %%
def size(obj):
    return "{0:.2f} MB".format(sys.getsizeof(obj) / (1000 * 1000))

print('orders -- dimensions: {0};   size: {1}'.format(orders.shape, size(orders)))
display(orders.head())
# Out:
# orders -- dimensions: (63629, 4);   size: 6.87 MB
#                     TXNDATE               TXNID    SKU  QUANTITY
# 295495  2017-12-01 04:04:14  171201090408778106  71356       2.0
# 295496  2017-12-01 04:05:41   17120109050837406  65065       1.0
# 295497  2017-12-01 04:06:15  171201090611267306  64187       1.0
# 295498  2017-12-01 04:12:01  171201091134149406  70064       2.0
# 295499  2017-12-01 04:12:59  171201091237342506  71669       1.0

# %%
# Convert from DataFrame to a Series, with order_id as index and item_id as value
orders = orders.set_index('TXNID')['SKU'].rename('item_id')
display(orders.head(10))
type(orders)
print('dimensions: {0};   size: {1};   unique_orders: {2};   unique_items: {3}'
      .format(orders.shape, size(orders), len(orders.index.unique()), len(orders.value_counts())))
# Out:
# TXNID
# 171201090408778106    71356
# 17120109050837406     65065
# 171201090611267306    64187
# 171201091134149406    70064
# 171201091237342506    71669
# 171201091348409206    71347
# 171201091540122306    65353
# 171201091540122306    71097
# 171201091540122306    71096
# 171201091540122306    69512
# Name: item_id, dtype: int64
# dimensions: (63629,);   size: 1.02 MB;   unique_orders: 24903;   unique_items: 7445

# %% [markdown]
# ## Helper functions to the main association rules function

# %%
# Returns frequency counts for items and item pairs
def freq(iterable):
    if type(iterable) == pd.core.series.Series:
        return iterable.value_counts().rename("freq")
    else: 
        return pd.Series(Counter(iterable)).rename("freq")

    
# Returns number of unique orders
def order_count(order_item):
    return len(set(order_item.index))


# Returns generator that yields item pairs, one at a time
def get_item_pairs(order_item):
    order_item = order_item.reset_index().as_matrix()
    for order_id, order_object in groupby(order_item, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
              
        for item_pair in combinations(item_list, 2):
            yield item_pair
            

# Returns frequency and support associated with item
def merge_item_stats(item_pairs, item_stats):
    return (item_pairs
                .merge(item_stats.rename(columns={'freq': 'freqA', 'support': 'supportA'}), left_on='item_A', right_index=True)
                .merge(item_stats.rename(columns={'freq': 'freqB', 'support': 'supportB'}), left_on='item_B', right_index=True))


# Returns name associated with item
def merge_item_name(rules, item_name):
    columns = ['itemA','itemB','groupA','groupB','freqAB','freqA','freqB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = (rules
                .merge(item_name.rename(columns={'item_name': 'itemA'}), left_on='item_A', right_on='item_id')
                .merge(item_name.rename(columns={'item_name': 'itemB'}), left_on='item_B', right_on='item_id'))
    return rules[columns] 

def merge_item_name2(rules, ML_Final):
    columns = ['item_A','item_B','groupA','groupB','freqAB','freqA','freqB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = rules.merge(ML_Final, left_on = 'item_A', right_on = 'SKU')
    rules = rules.rename(columns={'LABEL':'groupA','COST':'costA','MARGIN':'marginA','QUANTITY':'quantityA'})
    rules = rules.rename(columns={'COST_L':'costA_L','MARGIN_L':'marginA_L','QUANTITY_L':'quantityA_L'})
    rules = rules.merge(ML_Final, left_on = 'item_B', right_on = 'SKU')
    rules = rules.rename(columns={'LABEL':'groupB','COST':'costB','MARGIN':'marginB','QUANTITY':'quantityB'})
    rules = rules.rename(columns={'COST_L':'costB_L','MARGIN_L':'marginB_L','QUANTITY_L':'quantityB_L'})
    return rules

# %% [markdown]
# ## Association rules function

# %%
def association_rules(order_item, min_support):

    print("Starting order_item: {:22d}".format(len(order_item)))


    # Calculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100


    # Filter from order_item items below min support 
    qualifying_items       = item_stats[item_stats['support'] >= min_support].index
    order_item             = order_item[order_item.isin(qualifying_items)]

    print("Items with support >= {}: {:15d}".format(min_support, len(qualifying_items)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Filter from order_item orders with less than 2 items
    order_size             = freq(order_item.index)
    qualifying_orders      = order_size[order_size >= 2].index
    order_item             = order_item[order_item.index.isin(qualifying_orders)]

    print("Remaining orders with 2+ items: {:11d}".format(len(qualifying_orders)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Recalculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100


    # Get item pairs generator
    item_pair_gen          = get_item_pairs(order_item)


    # Calculate item pair frequency and support
    item_pairs              = freq(item_pair_gen).to_frame("freqAB")
    item_pairs['supportAB'] = item_pairs['freqAB'] / len(qualifying_orders) * 100

    print("Item pairs: {:31d}".format(len(item_pairs)))


    # Filter from item_pairs those below min support
    item_pairs              = item_pairs[item_pairs['supportAB'] >= min_support]

    print("Item pairs with support >= {}: {:10d}\n".format(min_support, len(item_pairs)))


    # Create table of association rules and compute relevant metrics
    item_pairs = item_pairs.reset_index().rename(columns={'level_0': 'item_A', 'level_1': 'item_B'})
    item_pairs = merge_item_stats(item_pairs, item_stats)
    
    item_pairs['confidenceAtoB'] = item_pairs['supportAB'] / item_pairs['supportA']
    item_pairs['confidenceBtoA'] = item_pairs['supportAB'] / item_pairs['supportB']
    item_pairs['lift']           = item_pairs['supportAB'] / (item_pairs['supportA'] * item_pairs['supportB'])
    
    
    # Return association rules sorted by lift in descending order
    return item_pairs.sort_values('lift', ascending=False)

# %%
# %%time
rules = association_rules(orders, 0.1)
# Out:
# Starting order_item:                  63629
# Items with support >= 0.1:             538
# Remaining order_item:                 28571
# Remaining orders with 2+ items:        6631
# Remaining order_item:                 18259
# Item pairs:                           15795
# Item pairs with support >= 0.1:        139
#
# CPU times: user 245 ms, sys: 46.9 ms, total: 292 ms
# Wall time: 284 ms

# %%
kmeans = KMeans(n_clusters=9)
kmeans.fit(mlDF[['COST','MARGIN','QUANTITY']])
mlDF['LABEL'] = kmeans.predict(mlDF[['COST','MARGIN','QUANTITY']])

# %%
LabelDF = mlDF.groupby(['LABEL']).agg({'COST': 'mean', 'MARGIN': 'mean', 'QUANTITY': 'mean'}).reset_index()
LabelDF=LabelDF.rename(columns={'COST':'COST_L','MARGIN':'MARGIN_L','QUANTITY':'QUANTITY_L'})
LabelDF.head(30)
# Out:
#    LABEL      COST_L  MARGIN_L  QUANTITY_L
# 0      0   10.508979  0.178980   34.043702
# 1      1  999.590000  0.500203    1.000000
# 2      2    9.891890  0.195253  256.416667
# 3      3    0.725000  0.261939  898.500000
# 4      4   90.360096  0.141947    3.867052
# 5      5   11.944525  0.134661   99.298429
# 6      6    9.623170  0.222412    5.350439
# 7      7  249.611667  0.123424    3.851852
# 8      8   34.118031  0.147846    4.623201

# %%
ML_Final = mlDF.merge(LabelDF, on='LABEL')

# %%
ML_Final.head()
# Out:
#      SKU   COST    MARGIN  QUANTITY  LABEL   COST_L  MARGIN_L  QUANTITY_L
# 0  50054   6.67  0.151244       2.0      6  9.62317  0.222412    5.350439
# 1  50234  20.84  0.227862       1.0      6  9.62317  0.222412    5.350439
# 2  50371   6.03  0.329255      10.0      6  9.62317  0.222412    5.350439
# 3  50409   9.34  0.150136       2.0      6  9.62317  0.222412    5.350439
# 4  50474   9.00  0.099099      15.0      6  9.62317  0.222412    5.350439

# %%
rules = merge_item_name2(rules, ML_Final)

# %%
# Replace item ID with item name and display association rules
item_name   = item_name[(item_name['DEPID'] != 65) & (item_name['DEPID'] != 21)]
item_name   = item_name.rename(columns={'SKU':'item_id', 'KEYWORD':'item_name'})
rules_final = merge_item_name(rules, item_name).sort_values('lift', ascending=False)

# %%
rules['MONTH']=12
rules.to_csv('Tableau/dec.csv')

# %%
rules_final
# Out:
#                                    itemA  \
# 13           MARLBORO MENTHOL GOLD 100'S
# 14               ANDRE EXTRA DRY  750 ML
# 15      19 CRIMES HARD CHARDONNAY 750 ML
# 31  CONCHA Y TORO FRONTERA MERLOT 1.5 LT
# 33             APOTHIC DARK 2013  750 ML
# 18      19 CRIMES HARD CHARDONNAY 750 ML
# 23         19 CRIMES SHIRAZ 2015  750 ML
# 12              PEANUTS ALL TYPES 2/1.09
# 21         19 CRIMES THE BANISHED 750 ML
# 20      19 CRIMES HARD CHARDONNAY 750 ML
# 40             CUPCAKE CHARDONNAY 750 ML
# 46                  CHRISTMAS RED 750 ML
# 49     WILLIAM HILL N COAST CHARD 750 ML
# 50           YELLOW TAIL CABERNET 1.5 LT
# 51   FRANCISCAN OAKVILLE CABERNET 750 ML
# 34             APOTHIC DARK 2013  750 ML
# 64      ZACCAGNINI MONTEPULCIANO  750 ML
# 16         19 CRIMES THE BANISHED 750 ML
# 65          ANDRE BRUT CHAMPAGNE  750 ML
# 66              WOODBRIDGE MERLOT 1.5 LT
# 29         19 CRIMES THE UPRISING 750 ML
# 25      19 CRIMES HARD CHARDONNAY 750 ML
# 67      YELLOW TAIL PINOT GRIGIO  1.5 LT
# 38             MENAGE A TROIS RED 750 ML
# 48               CHRISTMAS WHITE  750 ML
# 30      19 CRIMES HARD CHARDONNAY 750 ML
# 28         19 CRIMES SHIRAZ 2015  750 ML
# 68      DARK HORSE CABERNET SAUV  750 ML
# 69                WOODBRIDGE CAB  1.5 LT
# 70        NOBILO SAUVIGNON BLANC  750 ML
# ..                                   ...
# 10       SODA 12OZ CAN CASE 12 OZ SINGLE
# 58     RUFFINO RESERVA DUCALE TAN 750 ML
# 53            JOSH CABERNET  750 ML 2015
# 0                        SCHWEPPES  1 LT
# 45        COPPOLA DIAMOND MERLOT  750 ML
# 52    J LOHR CABERNET SEVEN OAKS  750 ML
# 60            JOSH CABERNET  750 ML 2015
# 76                                 LIMES
# 61            JOSH CABERNET  750 ML 2015
# 44             CUPCAKE CHARDONNAY 750 ML
# 83                          SODA 2 LITER
# 81            CAVIT PINOT GRIGIO  1.5 LT
# 62            JOSH CABERNET  750 ML 2015
# 4       OCEAN SPRAY CRANBERRY 64OZ 64 OZ
# 55            JOSH CABERNET  750 ML 2015
# 11       SODA 12OZ CAN CASE 12 OZ SINGLE
# 63            JOSH CABERNET  750 ML 2015
# 5                   JOHN JAMESON  750 ML
# 82            CAVIT PINOT GRIGIO  1.5 LT
# 80             LA MARCA PROSECCO  750 ML
# 6     CAPTAIN MORGAN SPICED RUM  1.75 LT
# 59            CAVIT PINOT GRIGIO  1.5 LT
# 1                        SCHWEPPES  1 LT
# 7              19 CRIMES CABERNET 750 ML
# 57            JOSH CABERNET  750 ML 2015
# 79             LA MARCA PROSECCO  750 ML
# 3             CAVIT PINOT GRIGIO  1.5 LT
# 2              LA MARCA PROSECCO  750 ML
# 8                              ICE CUBES
# 9      S MARGHERITA PINOT GRIGIO  750 ML
#
#                                     itemB  groupA  groupB  freqAB  freqA  \
# 13                      MARLBORO GOLD 100       0       5      13     17
# 14                STERLING VODKA  1.75 LT       5       0      10     34
# 15          19 CRIMES SHIRAZ 2015  750 ML       0       0       9     24
# 31      CONCHA Y TORO FRONTERA CAB 1.5 LT       0       5      11     26
# 33                   APOTHIC CRUSH 750 ML       0       5      12     31
# 18          19 CRIMES THE BANISHED 750 ML       0       5      12     24
# 23          19 CRIMES THE UPRISING 750 ML       0       0      11     36
# 12               PEANUTS ALL TYPES 2/1.09       5       5      18     47
# 21          19 CRIMES THE UPRISING 750 ML       5       0      17     57
# 20          19 CRIMES THE UPRISING 750 ML       0       0       7     24
# 40     CHAT ST JEAN CHARD N COAST  750 ML       5       0       7     44
# 46                CHRISTMAS WHITE  750 ML       2       5      32     77
# 49        WILLIAM HILL N COAST CAB 750 ML       5       5       9     43
# 50       YELLOW TAIL PINOT GRIGIO  1.5 LT       5       5       8     33
# 51         SIMI CABERNET SAUVIGNON 750 ML       0       5       8     26
# 34    MENAGE A TROIS MIDNIGHT 2013 750 ML       0       5       7     31
# 64        ZACCAGNINI PINOT GRIGIO  750 ML       5       0       9     48
# 16          19 CRIMES SHIRAZ 2015  750 ML       5       0      12     57
# 65                ANDRE EXTRA DRY  750 ML       5       5       8     41
# 66                 WOODBRIDGE CAB  1.5 LT       0       5       7     25
# 29              19 CRIMES CABERNET 750 ML       0       5      13     37
# 25              19 CRIMES CABERNET 750 ML       0       5       8     24
# 67         YELLOW TAIL CHARDONNAY  1.5 LT       5       5       7     36
# 38   MENAGE A TROIS SILK RED BLEND 750 ML       5       0       7     44
# 48       BAREFOOT WINTER RED BLEND 750 ML       5       2      12     56
# 30              19 CRIMES RED 2014 750 ML       0       5       7     24
# 28              19 CRIMES CABERNET 750 ML       0       5      11     36
# 68          DARK HORSE PINOT NOIR  750 ML       5       5       7     63
# 69                  WOODBRIDGE PG  1.5 LT       5       5       9     49
# 70      OYSTER BAY SAUV BLANC 2017 750 ML       5       5       7     26
# ..                                    ...     ...     ...     ...    ...
# 10    SPRING WATER 16OZ CASE 16 OZ SINGLE       2       5      11    117
# 58      S MARGHERITA PINOT GRIGIO  750 ML       5       2      16     63
# 53         SIMI CABERNET SAUVIGNON 750 ML       2       5      11    133
# 0        OCEAN SPRAY CRANBERRY 64OZ 64 OZ       2       0       8    126
# 45      KENDALL JACKSON V.R. CHARD 750 ML       0       2       7     37
# 52         SIMI CABERNET SAUVIGNON 750 ML       2       5       7     93
# 60  CHAT ST MICHELLE CAB SAUVIGNON 750 ML       2       5       7    133
# 76                        SCHWEPPES  1 LT       2       2      14     81
# 61             COPPOLA DIAMOND CAB 750 ML       2       5      10    133
# 44      KENDALL JACKSON V.R. CHARD 750 ML       5       2       7     44
# 83     CAPTAIN MORGAN SPICED RUM  1.75 LT       2       5       8    119
# 81             CAVIT PINOT GRIGIO  750 ML       2       5      10    127
# 62     J LOHR CABERNET SEVEN OAKS  750 ML       2       2      14    133
# 4          TITO'S HANDMADE VODKA  1.75 LT       0       2      10     41
# 55          COPPOLA DIAMOND CLARET 750 ML       2       5       9    133
# 11                        CANDY ALL TYPES       2       2       7    117
# 63                  BOGLE CABERNET 750 ML       2       5       7    133
# 5          TITO'S HANDMADE VODKA  1.75 LT       5       2      11     68
# 82               KORBEL EXTRA DRY  750 ML       2       5       7    127
# 80                RIONDO PROSECCO  750 ML       2       2       8    169
# 6          TITO'S HANDMADE VODKA  1.75 LT       5       2       7     57
# 59      S MARGHERITA PINOT GRIGIO  750 ML       2       2       9    127
# 1          TITO'S HANDMADE VODKA  1.75 LT       2       2      15    126
# 7          TITO'S HANDMADE VODKA  1.75 LT       5       2       7     65
# 57      S MARGHERITA PINOT GRIGIO  750 ML       2       2       8    133
# 79                    KORBEL BRUT  750 ML       2       2       8    169
# 3          TITO'S HANDMADE VODKA  1.75 LT       2       2       8    127
# 2          TITO'S HANDMADE VODKA  1.75 LT       2       2      10    169
# 8          TITO'S HANDMADE VODKA  1.75 LT       2       2       7    124
# 9          TITO'S HANDMADE VODKA  1.75 LT       2       2       7    148
#
#     freqB  confidenceAtoB  confidenceBtoA      lift
# 13     48        0.764706        0.270833  1.056409
# 14     23        0.294118        0.434783  0.847954
# 15     36        0.375000        0.250000  0.690729
# 31     41        0.423077        0.268293  0.684250
# 33     38        0.387097        0.315789  0.675484
# 18     57        0.500000        0.210526  0.581667
# 23     37        0.305556        0.297297  0.547605
# 12     47        0.382979        0.382979  0.540326
# 21     37        0.298246        0.459459  0.534505
# 20     37        0.291667        0.189189  0.522714
# 40     21        0.159091        0.333333  0.502348
# 46     56        0.415584        0.571429  0.492096
# 49     29        0.209302        0.310345  0.478581
# 50     36        0.242424        0.222222  0.446532
# 51     50        0.307692        0.160000  0.408062
# 34     37        0.225806        0.189189  0.404682
# 64     31        0.187500        0.290323  0.401069
# 16     36        0.210526        0.333333  0.387778
# 65     34        0.195122        0.235294  0.380545
# 66     49        0.280000        0.142857  0.378914
# 29     65        0.351351        0.200000  0.358432
# 25     65        0.333333        0.123077  0.340051
# 67     39        0.194444        0.179487  0.330605
# 38     32        0.159091        0.218750  0.329666
# 48     45        0.214286        0.266667  0.315762
# 30     62        0.291667        0.112903  0.311942
# 28     65        0.305556        0.169231  0.311714
# 68     25        0.111111        0.280000  0.294711
# 69     42        0.183673        0.214286  0.289985
# 70     62        0.269231        0.112903  0.287947
# ..    ...             ...             ...       ...
# 10     54        0.094017        0.203704  0.115450
# 58    148        0.253968        0.108108  0.113788
# 53     50        0.082707        0.220000  0.109686
# 0      41        0.063492        0.195122  0.102687
# 45    125        0.189189        0.056000  0.100361
# 52     50        0.075269        0.140000  0.099822
# 60     37        0.052632        0.189189  0.094324
# 76    126        0.172840        0.111111  0.090960
# 61     59        0.075188        0.169492  0.084504
# 44    125        0.159091        0.056000  0.084395
# 83     57        0.067227        0.140351  0.078207
# 81     69        0.078740        0.144928  0.075670
# 62     93        0.105263        0.150538  0.075054
# 4     252        0.243902        0.039683  0.064179
# 55     71        0.067669        0.126761  0.063199
# 11     67        0.059829        0.104478  0.059213
# 63     71        0.052632        0.098592  0.049155
# 5     252        0.161765        0.043651  0.042566
# 82     90        0.055118        0.077778  0.040610
# 80     82        0.047337        0.097561  0.038280
# 6     252        0.122807        0.027778  0.032315
# 59    148        0.070866        0.060811  0.031751
# 1     252        0.119048        0.059524  0.031326
# 7     252        0.107692        0.027778  0.028338
# 57    148        0.060150        0.054054  0.026950
# 79    127        0.047337        0.062992  0.024716
# 3     252        0.062992        0.031746  0.016575
# 2     252        0.059172        0.039683  0.015570
# 8     252        0.056452        0.027778  0.014854
# 9     252        0.047297        0.027778  0.012446
#
# [84 rows x 10 columns]
